# %% [markdown]
# <center>
#     <tr>
#     <td><img src="ontario-tech-univ-logo.png" width="25%"></img></td>
#     </tr>
# </center>

# %% [markdown]
# # OpenCV + Python setup
#
# Faisal Qureshi
# Professor
# Faculty of Science
# Ontario Tech University
# Oshawa ON Canada
# http://vclab.science.ontariotechu.ca

# %% [markdown]
# ## Import required packages

# %%
# Your solution here
import numpy as np
import scipy as sp
from scipy import signal
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load and display the image shown below
#
# <center>
#     <tr>
#     <td><img src="images/test.jpg" width="25%"></img></td>
#     </tr><br/>
#     data/test.jpg
# </center>

# %%
# Your solution here
I = cv.imread('data/test.jpg')
I = cv.cvtColor(I, cv.COLOR_BGR2RGB)
plt.figure(figsize=(7,7))
plt.imshow(I)

# %% [markdown]
# ## Print image height and width and the number of channels

# %%
# Your solution here
>>> print( I.shape )
# Out:
# (320, 260, 3)

# %% [markdown]
# ## Convert image to grayscale
#
# After conversion, the image will look something like this.
#
# <center>
#     <tr>
#     <td><img src="images/test_gray.jpg" width="25%"></img></td>
#     </tr>
# </center>

# %%
# Your solution here
I_gray = cv.imread('data/test.jpg')
I_gray = cv.cvtColor(I_gray, cv.COLOR_RGB2GRAY)
plt.figure(figsize=(6,6))
plt.imshow(I_gray, cmap='gray')

# %% [markdown]
# ## Print the height, width and the number of channels of the grayscale image

# %%
# Your solution here
>>> print( I_gray.shape )
# Out:
# (320, 260)

# %% [markdown]
# ## Save the grayscale image to file `test_gray.jpg`

# %%
# Your solution here
I_gray = cv.imread('data/test.jpg')
test_gray = cv.cvtColor(I_gray, cv.COLOR_RGB2GRAY)
plt.figure(figsize=(6,6))
plt.imshow(test_gray, cmap='gray')

I_gray = cv.imwrite('data/test_gray.jpg', test_gray)

# %% [markdown]
# ## Display the first frame from the video `data/traffic-short.mp4`
#
# 1. Open a video stream.
# 2. Read in the first frame.
# 3. Read in the second frame.
# 4. Find the differences between the two frames.
# 5. Display the first frame, the second frame and the differences as seen below.
# 6. Close the video stream
#
# <center>
#     <tr>
#     <td><img src="images/video-frames.png" width="75%"></img></td>
#     </tr>
# </center>

# %%
# Your solution here
import numpy as np
import scipy as sp
from scipy import signal
import cv2 as cv
import matplotlib.pyplot as plt

cap = cv.VideoCapture('data/traffic-short.mp4')
retvalue1, first_frame= cap.read()
retvalue2, second_frame=cap.read()

difference_between_frames = first_frame - second_frame

fig,image_array = plt.subplots(1,3, figsize=(30,30))
image_array[0].imshow(first_frame)
image_array[1].imshow(second_frame)
image_array[2].imshow(difference_between_frames)

# %% [markdown]
# ## Capture a frame from webcam
#
# 1. Open a camera stream.
# 2. Read in one frame.
# 3. Read in another frame.
# 4. Find the differences between the two frames.
# 5. Display the first frame, the second frame and the differences as seen below (your frames will be different).
# 6. Close the video stream
#
# <center>
#     <tr>
#     <td><img src="images/camera-capture.png" width="75%"></img></td>
#     </tr>
# </center>

# %%
# Your solution here

# %% [markdown]
# <center>
#     <tr>
#     <td><img src="ontario-tech-univ-logo.png" width="25%"></img></td>
#     </tr>
# </center>
