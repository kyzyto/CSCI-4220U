# %% [markdown]
# <center>
#     <tr>
#         <td><img src="ontario-tech-univ-logo.png" width="25%"></img></td>
#      </tr>
# </center>

# %% [markdown]
# # Hybrid images
#
# Faisal Qureshi\
# Professor\
# Faculty of Science\
# Ontario Tech University\
# Oshawa ON Canada\
# http://vclab.science.ontariotechu.ca

# %% [markdown]
# ## **Outline**
#
#
# *   Image pyramids
# *   Hybrid images

# %% [markdown]
# ## **Task**
# The goal is to laboratory is to construct hybrid images as suggested by Oliva et al. in their Siggraph 2006 paper [[doi](https://dl.acm.org/doi/10.1145/1141911.1141919)]. A hybrid image is static images which changes as a function of viewing distance. Check out the following image taken from Wikipedia article on hybrid image. View this image from up close. You will read "southeast." Now move away from your monitor. As you get farther away from your display, it reads "northwest." How can that be? This image combines low-frequency component of one image (that reads "northwest") and high-frequency component of the other image (that reads "southeast"). Human visual system picks up high-frequency component up close and is unable to pick high-frequency components from a distance. Therefore, from a distance the text reads "northwest."

# %% [markdown]
# <center>
#     <tr>
#         <td><img src="data/south-east.png" width="25%"></img></td>
#      </tr>
# </center>

# %% [markdown]
# If you don't feel like moving away from your desk. You can always "simulate" this effect by zooming out the image.

# %% [markdown]
# ## **Recipe**
# Given two images A and B
#
# * Construct laplacian pyramid of image A
# * Construct laplacian pyramid of image B
# * Construct a new pyramid that takes some levels from A and others from B, recall that different levels of a laplacian pyramid captures signals at different frequencies
# * Reconstruct the image from this new pyramid
# * Voila<br>
#
# For this to work properly, you will need to fidget how many levels you copy from laplacian pyramid for image A and how many levels you copy from laplacian pyramid for image B. Furthermore, you should pick high-frequency component from images that exhibit higher spatial frequency (i.e., lots of edges and texture).

# %% [markdown]
# ## **Starter code**
# Use the code below to get things going

# %%
import cv2 as cv
import numpy as np
import scipy as sp
from scipy import signal
import matplotlib.pyplot as plt

# %%
img1 = cv.imread('data/dog.bmp')
img1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
img1 = cv.resize(img1, (2048, 2048))

img2 = cv.imread('data/cat1.bmp')
img2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)
img2 = cv.resize(img2, (2048, 2048))


plt.figure(figsize=(10,5))
plt.subplot(121)
plt.title('cat')
plt.imshow(img1, cmap='gray')
plt.xticks([])
plt.yticks([]);
plt.subplot(122)
plt.title('DeCaprio')
plt.imshow(img2, cmap='gray')
plt.xticks([])
plt.yticks([]);

# %%
# Your solution goes here
def gen_gaussian_pyramid(I, levels):
    G = I.copy()
    gpI = [G]
    for i in range(levels):
        G = cv.pyrDown(G)
        gpI.append(G)
    return gpI

gpdog = gen_gaussian_pyramid(img1, 11)
gpcat = gen_gaussian_pyramid(img2, 11)



def gen_laplacian_pyramid(gpI):
    """gpI is a Gaussian pyramid generated using gen_gaussian_pyramid method found in py file of the same name."""
    num_levels = len(gpI)-1
    lpI = [gpI[num_levels]]
    for i in range(num_levels,0,-1):
        GE = cv.pyrUp(gpI[i])
        L = cv.subtract(gpI[i-1],GE)
        lpI.append(L)
    return lpI

lpdog = gen_laplacian_pyramid(gpdog)
lpcat = gen_laplacian_pyramid(gpcat)

# %%
def construct_hybrid_pyramid(img1, img2, level_range):
    LS = []
    level = 0
    for l1, l2 in zip(img1, img2):
        if(level > level_range):
            LS.append(l2)
        else:
            LS.append(l1)
        level = level+1
    return LS
 
    
def reconstruct_from_laplacian_pyramid(lp):
    num_levels = len(lp)
    ls_ = lp[0]
    for i in range(1,num_levels):
        ls_ = cv.pyrUp(ls_)
        ls_ = cv.add(ls_, lp[i])
    return ls_


hp_cd = construct_hybrid_pyramid(lpdog, lpcat,6)
cat_dog = reconstruct_from_laplacian_pyramid(hp_cd)

plt.figure(figsize=(5,5))
plt.imshow(cat_dog, cmap='gray')

# %%
def gen_gaussian_pyramid(I, levels):
    G = I.copy()
    gpI = [G]
    for i in range(levels):
        G = cv.pyrDown(G)
        gpI.append(G)
    return gpI

def gen_laplacian_pyramid(gpI):
    """gpI is a Gaussian pyramid generated using gen_gaussian_pyramid method found in py file of the same name."""
    num_levels = len(gpI)-1
    lpI = [gpI[num_levels]]
    for i in range(num_levels,0,-1):
        GE = cv.pyrUp(gpI[i])
        L = cv.subtract(gpI[i-1],GE)
        lpI.append(L)
    return lpI


h11 = cv.imread('data/h11.jpg')
h12 = cv.imread('data/h12.jpg')
h11 = cv.cvtColor(h11, cv.COLOR_BGR2RGB)
h12 = cv.cvtColor(h12, cv.COLOR_BGR2RGB)
h11 = cv.resize(h11, (2048, 2048))
h12 = cv.resize(h12, (2048, 2048))


gph11 = gen_gaussian_pyramid(h11, 9)
gph12 = gen_gaussian_pyramid(h12, 9)

gp = gph12
num_levels = len(gp)
print('Guassian Pyramid')
for i in range(num_levels):
    rows = gp[i].shape[0]
    cols = gp[i].shape[1]
    print('level={}: size={}x{}'.format(i, rows, cols))
    
lph11 = gen_laplacian_pyramid(gph11)
lph12 = gen_laplacian_pyramid(gph12)

lp = lph11
num_levels = len(lp)
print(' ')
print('Laplacian Pyramid')
for i in range(num_levels):
    rows = lp[i].shape[0]
    cols = lp[i].shape[1]
    print('level={}: size={}x{}'.format(i, cols, rows))
    
LS = []
for lh11, lh12 in zip(lph12,lph11):
    rows, cols, dpt = lh11.shape
    ls = np.hstack((lh11[:,0:cols//2,:], lh12[:,cols//2:,:]))
    LS.append(ls)

def reconstruct_from_laplacian_pyramid(lp):
    num_levels = len(lp)
    ls_ = lp[0]
    for i in range(1,num_levels):
        ls_ = cv.pyrUp(ls_)
        ls_ = cv.add(ls_, lp[i])
    return ls_


ls_ = reconstruct_from_laplacian_pyramid(LS)
real = np.hstack((A[:,:cols//2],B[:,cols//2:]))


plt.figure(figsize=(10,10))
ls_gray = cv.cvtColor(ls_, cv.COLOR_BGR2GRAY)
plt.imshow(ls_gray,cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-be140c7a795e> in <module>
#      18
#      19
# ---> 20 h11 = cv.imread('data/h11.jpg')
#      21 h12 = cv.imread('data/h12.jpg')
#      22 h11 = cv.cvtColor(h11, cv.COLOR_BGR2RGB)
#
# NameError: name 'cv' is not defined

# %%
h21 = cv.imread('data/h21.jpg')
h22 = cv.imread('data/h22.jpg')
h21 = cv.cvtColor(h21, cv.COLOR_BGR2RGB)
h22 = cv.cvtColor(h22, cv.COLOR_BGR2RGB)
h21 = cv.resize(h21, (2048, 2048))
h22 = cv.resize(h22, (2048, 2048))


gph21 = gen_gaussian_pyramid(h21, 9)
gph22 = gen_gaussian_pyramid(h22, 9)

gp = gph22
num_levels = len(gp)
print('Guassian Pyramid')
for i in range(num_levels):
    rows = gp[i].shape[0]
    cols = gp[i].shape[1]
    print('level={}: size={}x{}'.format(i, rows, cols))
    
lph21 = gen_laplacian_pyramid(gph21)
lph22 = gen_laplacian_pyramid(gph22)

lp = lph21
num_levels = len(lp)
print(' ')
print('Laplacian Pyramid')
for i in range(num_levels):
    rows = lp[i].shape[0]
    cols = lp[i].shape[1]
    print('level={}: size={}x{}'.format(i, cols, rows))
    
LS = []
for lh21, lh22 in zip(lph22,lph21):
    rows, cols, dpt = lh21.shape
    ls = np.hstack((lh21[:,0:cols//2,:], lh22[:,cols//2:,:]))
    LS.append(ls)

mergeImage=[]
for x in range(num_levels):
    if x > 7:
        mergeImage.append(h21[x])
    else:
        mergeImage.append(h22[x])
    
    
def reconstruct_from_laplacian_pyramid(lp):
    num_levels = len(lp)
    ls_ = lp[0]
    for i in range(1,num_levels):
        ls_ = cv.pyrUp(ls_)
        ls_ = cv.add(ls_, lp[i])
    return ls_


ls_ = reconstruct_from_laplacian_pyramid(LS)


plt.figure(figsize=(10,10))
ls_gray = cv.cvtColor(ls_, cv.COLOR_BGR2GRAY)
plt.imshow(ls_gray,cmap='gray')
# Out:
# Guassian Pyramid
# level=0: size=2048x2048
# level=1: size=1024x1024
# level=2: size=512x512
# level=3: size=256x256
# level=4: size=128x128
# level=5: size=64x64
# level=6: size=32x32
# level=7: size=16x16
# level=8: size=8x8
# level=9: size=4x4
#
# Laplacian Pyramid
# level=0: size=4x4
# level=1: size=8x8
# level=2: size=16x16
# level=3: size=32x32
# level=4: size=64x64
# level=5: size=128x128
# level=6: size=256x256
# level=7: size=512x512
# level=8: size=1024x1024
# level=9: size=2048x2048

# %%
h31 = cv.imread('data/h31.jpg')
h33 = cv.imread('data/h33.jpg')
h31 = cv.cvtColor(h31, cv.COLOR_BGR2RGB)
h33 = cv.cvtColor(h33, cv.COLOR_BGR2RGB)
h31 = cv.resize(h31, (2048, 2048))
h33 = cv.resize(h33, (2048, 2048))


gph31 = gen_gaussian_pyramid(h31, 9)
gph33 = gen_gaussian_pyramid(h33, 9)

gp = gph33
num_levels = len(gp)
print('Guassian Pyramid')
for i in range(num_levels):
    rows = gp[i].shape[0]
    cols = gp[i].shape[1]
    print('level={}: size={}x{}'.format(i, rows, cols))
    
lph31 = gen_laplacian_pyramid(gph31)
lph33 = gen_laplacian_pyramid(gph33)

lp = lph31
num_levels = len(lp)
print(' ')
print('Laplacian Pyramid')
for i in range(num_levels):
    rows = lp[i].shape[0]
    cols = lp[i].shape[1]
    print('level={}: size={}x{}'.format(i, cols, rows))
    
LS = []
for lh31, lh33 in zip(lph33,lph31):
    rows, cols, dpt = lh31.shape
    ls = np.hstack((lh31[:,0:cols//2,:], lh33[:,cols//2:,:]))
    LS.append(ls)

mergeImage=[]
for x in range(num_levels):
    if x > 7:
        mergeImage.append(h31[x])
    else:
        mergeImage.append(h33[x])
    
    
def reconstruct_from_laplacian_pyramid(lp):
    num_levels = len(lp)
    ls_ = lp[0]
    for i in range(1,num_levels):
        ls_ = cv.pyrUp(ls_)
        ls_ = cv.add(ls_, lp[i])
    return ls_


ls_ = reconstruct_from_laplacian_pyramid(LS)



plt.figure(figsize=(10,10))
ls_gray = cv.cvtColor(ls_, cv.COLOR_BGR2GRAY)
plt.imshow(ls_gray,cmap='gray')
# Out:
# Guassian Pyramid
# level=0: size=2048x2048
# level=1: size=1024x1024
# level=2: size=512x512
# level=3: size=256x256
# level=4: size=128x128
# level=5: size=64x64
# level=6: size=32x32
# level=7: size=16x16
# level=8: size=8x8
# level=9: size=4x4
#
# Laplacian Pyramid
# level=0: size=4x4
# level=1: size=8x8
# level=2: size=16x16
# level=3: size=32x32
# level=4: size=64x64
# level=5: size=128x128
# level=6: size=256x256
# level=7: size=512x512
# level=8: size=1024x1024
# level=9: size=2048x2048

# %%
E = cv.imread('data/einstein.bmp')
M = cv.imread('data/marilyn.bmp')
E = cv.cvtColor(E, cv.COLOR_BGR2RGB)
M = cv.cvtColor(M, cv.COLOR_BGR2RGB)
E = cv.resize(E, (2048, 2048))
M = cv.resize(M, (2048, 2048))


gpE = gen_gaussian_pyramid(E, 9)
gpM = gen_gaussian_pyramid(M, 9)

gp = gpE
num_levels = len(gp)
print('Guassian Pyramid')
for i in range(num_levels):
    rows = gp[i].shape[0]
    cols = gp[i].shape[1]
    print('level={}: size={}x{}'.format(i, rows, cols))
    
lpE = gen_laplacian_pyramid(gpE)
lpM = gen_laplacian_pyramid(gpM)

lp = lpM
num_levels = len(lp)
print(' ')
print('Laplacian Pyramid')
for i in range(num_levels):
    rows = lp[i].shape[0]
    cols = lp[i].shape[1]
    print('level={}: size={}x{}'.format(i, cols, rows))
    
LS = []
for lE, lM in zip(lpM,lpE):
    rows, cols, dpt = lE.shape
    ls = np.hstack((lE[:,0:cols//2,:], lM[:,cols//2:,:]))
    LS.append(ls)

mergeImage=[]
for x in range(num_levels):
    if x > 7:
        mergeImage.append(E[x])
    else:
        mergeImage.append(M[x])
    
    
def reconstruct_from_laplacian_pyramid(lp):
    num_levels = len(lp)
    ls_ = lp[0]
    for i in range(1,num_levels):
        ls_ = cv.pyrUp(ls_)
        ls_ = cv.add(ls_, lp[i])
    return ls_


ls_ = reconstruct_from_laplacian_pyramid(LS)



plt.figure(figsize=(10,10))
ls_gray = cv.cvtColor(ls_, cv.COLOR_BGR2GRAY)
plt.imshow(ls_gray,cmap='gray')
# Out:
# Guassian Pyramid
# level=0: size=2048x2048
# level=1: size=1024x1024
# level=2: size=512x512
# level=3: size=256x256
# level=4: size=128x128
# level=5: size=64x64
# level=6: size=32x32
# level=7: size=16x16
# level=8: size=8x8
# level=9: size=4x4
#
# Laplacian Pyramid
# level=0: size=4x4
# level=1: size=8x8
# level=2: size=16x16
# level=3: size=32x32
# level=4: size=64x64
# level=5: size=128x128
# level=6: size=256x256
# level=7: size=512x512
# level=8: size=1024x1024
# level=9: size=2048x2048

# %% [markdown]
# ## **Test on other images**
# Now construct hybrid images from (h11.jpg, h12.jpg), (h21.jpg h22.jpg), (h31.jpg h33.jpg), and (einstein.bmp, marilyn.bmp) images found in the data folder.

# %% [markdown]
# ## **Submission**
# Include code and all hybrid images in a single jupyter notebook.
#
# Submit via canvas.

# %% [markdown]
# <center>
#     <tr>
#         <td><img src="ontario-tech-univ-logo.png" width="25%"></img></td>
#      </tr>
# </center>
